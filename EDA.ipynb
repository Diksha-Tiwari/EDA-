# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('companies.csv')

# %%
df
# Out:
#              id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0           c:1             0     Company          1        NaN
# 1          c:10             1     Company         10        NaN
# 2         c:100             2     Company        100        NaN
# 3       c:10000             3     Company      10000        NaN
# 4       c:10001             4     Company      10001        NaN
# ...         ...           ...         ...        ...        ...
# 196548  c:99940        196548     Company      99940        NaN
# 196549   c:9995        196549     Company       9995        NaN
# 196550   c:9996        196550     Company       9996        NaN
# 196551   c:9997        196551     Company       9997        NaN
# 196552   c:9998        196552     Company       9998        NaN
#
#                       name     normalized_name                    permalink  \
# 0                 Wetpaint            wetpaint            /company/wetpaint
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at', 'lat', 'lng', 'ROI'],
#       dtype='object')

# %%
cols=['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
       'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
       'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
       'logo_width', 'logo_height', 'short_description', 'description',
       'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
       'first_investment_at', 'last_investment_at', 'investment_rounds',
       'invested_companies', 'first_funding_at', 'last_funding_at',
       'funding_rounds', 'funding_total_usd', 'first_milestone_at',
       'last_milestone_at', 'milestones', 'relationships', 'created_by',
       'created_at', 'updated_at', 'lat', 'lng', 'ROI']

# %%
df.columns=cols

# %%
df.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# Unnamed: 0.1                0
# entity_type                 0
# entity_id                   0
# parent_id              196553
# name                       22
# normalized_name            26
# permalink                   0
# category_code           73367
# status                      0
# founded_at             105326
# closed_at              193933
# domain                  70008
# homepage_url            70008
# twitter_username       115962
# logo_url                86443
# logo_width              86443
# logo_height             86443
# short_description      189422
# description            104505
# overview                69582
# tag_list               115101
# country_code           108563
# state_code             145650
# city                   112663
# region                      0
# first_investment_at    193970
# last_investment_at     193970
# investment_rounds      193962
# invested_companies     193962
# first_funding_at       165046
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   196553 non-null  object
#  1   Unnamed: 0.1         196553 non-null  int64
#  2   entity_type          196553 non-null  object
#  3   entity_id            196553 non-null  int64
#  4   parent_id            0 non-null       float64
#  5   name                 196531 non-null  object
#  6   normalized_name      196527 non-null  object
#  7   permalink            196553 non-null  object
#  8   category_code        123186 non-null  object
#  9   status               196553 non-null  object
#  10  founded_at           91227 non-null   object
#  11  closed_at            2620 non-null    object
#  12  domain               126545 non-null  object
#  13  homepage_url         126545 non-null  object
#  14  twitter_username     80591 non-null   object
# ...

# %%
for col in df.columns:
    print('{} : {}'.format(col,df[col].unique()))
# Out:
# id : ['c:1' 'c:10' 'c:100' ... 'c:9996' 'c:9997' 'c:9998']
# Unnamed: 0.1 : [     0      1      2 ... 196550 196551 196552]
# entity_type : ['Company']
# entity_id : [   1   10  100 ... 9996 9997 9998]
# parent_id : [nan]
# name : ['Wetpaint' 'Flektor' 'There' ... 'CSC' 'Top-candidate' 'Closet Couture']
# normalized_name : ['wetpaint' 'flektor' 'there' ... 'csc' 'top candidate' 'closet couture']
# permalink : ['/company/wetpaint' '/company/flektor' '/company/there' ...
#  '/company/csc' '/company/top-candidate' '/company/closet-couture']
# category_code : ['web' 'games_video' 'network_hosting' 'advertising' 'cleantech' nan
#  'enterprise' 'other' 'consulting' 'mobile' 'health' 'software'
#  'analytics' 'finance' 'education' 'medical' 'manufacturing' 'biotech'
#  'ecommerce' 'public_relations' 'hardware' 'search' 'news' 'government'
#  'security' 'photo_video' 'travel' 'semiconductor' 'social' 'legal'
#  'transportation' 'hospitality' 'sports' 'nonprofit' 'fashion' 'messaging'
# ...

# %%
for col in df.columns:
    df[col].replace({'?':np.nan},inplace=True)

# %%
df.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# Unnamed: 0.1                0
# entity_type                 0
# entity_id                   0
# parent_id              196553
# name                       22
# normalized_name            26
# permalink                   0
# category_code           73367
# status                      0
# founded_at             105326
# closed_at              193933
# domain                  70008
# homepage_url            70008
# twitter_username       115962
# logo_url                86443
# logo_width              86443
# logo_height             86443
# short_description      189423
# description            104505
# overview                69582
# tag_list               115101
# country_code           108563
# state_code             145650
# city                   112666
# region                      0
# first_investment_at    193970
# last_investment_at     193970
# investment_rounds      193962
# invested_companies     193962
# first_funding_at       165046
# ...

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
num_col = ['entity_id','milestones','relationships','ROI']
for col in num_col:
    df[col]=pd.to_numeric(df[col])
    df[col].fillna(df[col].mean(),inplace=True)
df.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 1.How does the milestones affect the price?

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='milestones',y='lat',data=df)              
plt.xlabel('Milestones')
plt.ylabel('LAT')
# Out:
# Text(0, 0.5, 'LAT')

# %%
sns.histplot(df.milestones,bins=10)
# Out:
# <AxesSubplot:xlabel='milestones', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='milestones',y='relationships',data=df)
plt.xlabel('Milestones')
plt.ylabel('Relationships')
# Out:
# Text(0, 0.5, 'Relationships')

# %%
df.investment_rounds.value_counts()
# Out:
# 1.0      1957
# 2.0       299
# 3.0       125
# 4.0        51
# 5.0        33
# 6.0        24
# 7.0        17
# 8.0        16
# 9.0         9
# 12.0        5
# 30.0        4
# 17.0        4
# 14.0        4
# 18.0        3
# 11.0        3
# 15.0        3
# 10.0        3
# 24.0        2
# 40.0        2
# 20.0        2
# 37.0        2
# 16.0        2
# 29.0        2
# 19.0        2
# 38.0        1
# 68.0        1
# 33.0        1
# 44.0        1
# 58.0        1
# 125.0       1
# 13.0        1
# 96.0        1
# 297.0       1
# 89.0        1
# 478.0       1
# 22.0        1
# 21.0        1
# 49.0        1
# 25.0        1
# 32.0        1
# 51.0        1
# Name: investment_rounds, dtype: int64

# %%
sns.boxplot(x='lat',y='investment_rounds',data=df)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='investment_rounds'>
